# %%
import pandas as pd

# %%
df = pd.read_csv('/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/patient_description_sir_Suffian/PI-PD-20 consolidated.tsv',sep = '\t')

# %%
df.count()
# Out:
# Label         11104
# Discussion    11104
# dtype: int64

# %%
unique_labels = df['Label'].unique()
unique_labels
# Out:
# array(['acne', 'Appendicitis', 'Asthma', 'B12 Deficiency', 'Cancer',
#        'Cataract', 'Conjunctivitis', 'Cough', 'Dengue Fever', 'Headache',
#        'Heart Attack', 'Hepatitis', 'hernia', 'Hypertension',
#        'Otitis Media', 'Piles', 'Urinary Tract Infection',
#        'Urticarial Rash', 'Stroke & Tia', 'Alzheimer'], dtype=object)

# %%
labels_count = df['Label'].value_counts()
labels_count
# Out:
# Label
# Conjunctivitis             1216
# Heart Attack               1102
# Cataract                   1071
# Piles                      1035
# Hypertension                884
# hernia                      822
# Otitis Media                705
# Headache                    703
# Cancer                      600
# Urinary Tract Infection     591
# Cough                       512
# B12 Deficiency              443
# Urticarial Rash             296
# Asthma                      246
# Stroke & Tia                231
# Dengue Fever                219
# acne                        177
# Appendicitis                122
# Hepatitis                    76
# Alzheimer                    53
# Name: count, dtype: int64
