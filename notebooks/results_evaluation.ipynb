# %%
import pandas as pd

# %%
file_path = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/medical_parameter_extraction_pipeline/structured_queries_symptoms.jsonl"
file_path_org = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/medical_parameter_extraction_pipeline/structured_queries-org.jsonl"

# %%
df = pd.read_json(file_path, lines=True)
df
# Out:
#                                           original_text  \
# 0     can someone help?! I've had bumps like this of...
# 1     I started getting acne since the age of 14 (I'...
# 2     So i've been breaking out badly lately. I want...
# 3     16 year old kid, about 3 years ago he was give...
# 4     Been breaking out a lot due to this lockdown. ...
# ...                                                 ...
# 9056  I have a recurring UTI now for 5-6 months. I'm...
# 9057  Hey I am 9 weeks and 5 days pregnant have bad ...
# 9058  I've found a solution to my hives, and I just ...
# 9059  Hey everyone, my heart goes out to all you suf...
# 9060  Hi everyone,My mother has recently started wan...
#
#                         label             category  \
# 0                        acne          Dermatology
# 1                        acne          Dermatology
# 2                        acne          Dermatology
# 3                        acne          Dermatology
# ...

# %%
df_org = pd.read_json(file_path_org, lines=True)
df_org
# Out:
#                                                symptoms  \
# 0     [{'name': 'bumps', 'anatomical_location': '', ...
# 1     [{'name': 'acne', 'anatomical_location': 'face...
# 2     [{'name': 'acne', 'anatomical_location': 'skin...
# 3     [{'name': 'red cheeks', 'anatomical_location':...
# 4     [{'name': 'acne', 'anatomical_location': 'skin...
# ...                                                 ...
# 2971  [{'name': 'floaters', 'anatomical_location': '...
# 2972  [{'name': 'vertical double vision', 'anatomica...
# 2973  [{'name': 'eye burning', 'anatomical_location'...
# 2974  [{'name': 'red eye', 'anatomical_location': 'e...
# 2975                                                 []
#
#                                                duration severity_overall  \
# 0     {'value': 'a couple months', 'normalized_days'...
# 1     {'value': '6 years', 'normalized_days': 2190, ...           severe
# 2     {'value': 'lately', 'normalized_days': 14, 'on...         moderate
# ...

# %%
# df = df.rename(columns={"symptoms": "symptoms_df"})
df_org = df_org.rename(columns={"symptoms": "symptoms_org"})

# %%
df_merge = pd.merge(df, df_org, on="original_text", how="inner")
df_merge = df_merge[["original_text", "symptoms", "symptoms_org"]]
df_merge
# Out:
#                                          original_text  \
# 0    can someone help?! I've had bumps like this of...
# 1    I started getting acne since the age of 14 (I'...
# 2    So i've been breaking out badly lately. I want...
# 3    16 year old kid, about 3 years ago he was give...
# 4    Been breaking out a lot due to this lockdown. ...
# ..                                                 ...
# 946  I was diagnosed with low B12 levels and furthe...
# 947  Earlier this year I was diagnosed with b12 def...
# 948  I'm b12 deficiency. I was diagnosed with vitam...
# 949  Hello there I am booked in to have my first B1...
# 950  I have been going to my docs for over a year w...
#
#                                               symptoms  \
# 0    [{'name': 'bumps', 'normalized_name': None, 'a...
# 1    [{'name': 'acne', 'normalized_name': None, 'an...
# 2    [{'name': 'acne', 'normalized_name': None, 'an...
# 3    [{'name': 'redness', 'normalized_name': None, ...
# ...

# %%
df_merge.to_csv("/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/merged_results_symptoms.csv", index=False)

# %%
df_org = df_org[['original_text','symptoms']]
df_org.to_csv("/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/symptoms_org.csv", index=False)

# %%
df = df[['original_text','symptoms']]
df.to_csv("/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/symptoms.csv", index=False)

# %%
df = pd.read_json(file_path, lines=True)

# %%
len(df.severity_overall)
# Out:
# 831

# %%
file_path = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/medical_parameter_extraction_pipeline/structured_queries_symptoms.jsonl"

data = []

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        data.append(line)

print(data)
# Out:
# ['{"original_text": "can someone help?! I\'ve had bumps like this off and on for a couple months now and I\'m not sure if I am having an allergic reaction to something or if I\'m starting to get acne. Any advice is appreciated!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "bumps", "normalized_name": "bumps", "anatomical_location": "", "severity": ""}]}\n', '{"original_text": "I started getting acne since the age of 14 (I\'m 20 now). sometimes it is severe and sometimes it clears out completely. from the past 2 weeks i\'m having severe acne. it is big, painful and red. I don\'t know what type of acne this is. can someone tell me what i should do to clear this.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "big, painful and red acne", "normalized_name": "acne lesions", "anatomical_location": "", "severity": "severe"}]}\n', '{"original_text": "So i\'ve been breaking out badly lately. I want to try some home remedies, i saw that using colgate 
# ...

# %%
f = open(file_path, 'r')
    # Parsing the JSON file into a Python dictionary
for line in f:
    print(line)
# Out:
# {"original_text": "can someone help?! I've had bumps like this off and on for a couple months now and I'm not sure if I am having an allergic reaction to something or if I'm starting to get acne. Any advice is appreciated!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "bumps", "normalized_name": "bumps", "anatomical_location": "", "severity": ""}]}
#
# {"original_text": "I started getting acne since the age of 14 (I'm 20 now). sometimes it is severe and sometimes it clears out completely. from the past 2 weeks i'm having severe acne. it is big, painful and red. I don't know what type of acne this is. can someone tell me what i should do to clear this.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "big, painful and red acne", "normalized_name": "acne lesions", "anatomical_location": "", "severity": "severe"}]}
#
# ...

# %%
f[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f[0]
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
# Out:
# _io.TextIOWrapper
