# %%
import pandas as pd

# %%
file_path = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/intelligent_scraping/structured_queries.jsonl"
file_path_org = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/intelligent_scraping/structured_queries-org.jsonl"

# %%
df = pd.read_json(file_path, lines=True)
df
# Out:
#                                          original_text           label  \
# 0    can someone help?! I've had bumps like this of...            acne
# 1    I started getting acne since the age of 14 (I'...            acne
# 2    So i've been breaking out badly lately. I want...            acne
# 3    16 year old kid, about 3 years ago he was give...            acne
# 4    Been breaking out a lot due to this lockdown. ...            acne
# ..                                                 ...             ...
# 826  I was diagnosed with low B12 levels and furthe...  B12 Deficiency
# 827  Earlier this year I was diagnosed with b12 def...  B12 Deficiency
# 828  I'm b12 deficiency. I was diagnosed with vitam...  B12 Deficiency
# 829  Hello there I am booked in to have my first B1...  B12 Deficiency
# 830  I have been going to my docs for over a year w...  B12 Deficiency
#
#                      category  \
# 0                 Dermatology
# 1                 Dermatology
# 2                 Dermatology
# 3                 Dermatology
# 4                 Dermatology
# ..                        ...
# 826  Hematology / Nutritional
# 827  Hematology / Nutritional
# 828  Hematology / Nutritional
# 829  Hematology / Nutritional
# 830  Hematology / Nutritional
#
#                                               symptoms  \
# 0    [{'name': 'bumps', 'normalized_name': None, 'a...
# 1    [{'name': 'acne', 'normalized_name': None, 'an...
# 2    [{'name': 'acne', 'normalized_name': None, 'an...
# 3    [{'name': 'redness', 'normalized_name': None, ...
# 4    [{'name': 'acne', 'normalized_name': None, 'an...
# ..                                                 ...
# 826  [{'name': 'vague feeling', 'normalized_name': ...
# 827  [{'name': 'memory loss', 'normalized_name': No...
# 828  [{'name': 'sore tongue', 'normalized_name': No...
# 829  [{'name': 'pins and needles', 'normalized_name...
# 830  [{'name': 'headaches', 'normalized_name': None...
#
#                                               duration severity_overall  \
# 0    {'value': 'a couple months', 'normalized_days'...
# 1    {'value': '6 years', 'normalized_days': 2190, ...           severe
# 2    {'value': 'lately', 'normalized_days': 7, 'ons...         moderate
# 3    {'value': '3 years', 'normalized_days': 1095, ...
# 4    {'value': '', 'normalized_days': 0, 'onset_typ...
# ..                                                 ...              ...
# 826  {'value': '6 weeks since last injection', 'nor...
# 827  {'value': 'earlier this year', 'normalized_day...
# 828  {'value': 'since December 12th 2014', 'normali...
# 829  {'value': '', 'normalized_days': 0, 'onset_typ...
# 830  {'value': 'over a year', 'normalized_days': 36...
#
#                                   anatomical_locations  \
# 0                                                   []
# 1                                               [face]
# 2                                               [skin]
# 3                     [cheeks, chin, between eyebrows]
# 4                                               [skin]
# ..                                                 ...
# 826                                                 []
# 827                    [brain, gastrointestinal tract]
# 828                            [tongue, roof of mouth]
# 829                                [left foot, tongue]
# 830  [head, respiratory system, chest, speech, mout...
#
#                                           demographics       intent  red_flag  \
# 0    {'age': None, 'age_group': '', 'gender': '', '...    diagnosis     False
# 1    {'age': 20, 'age_group': 'adult', 'gender': ''...    treatment     False
# 2    {'age': None, 'age_group': '', 'gender': '', '...    treatment     False
# 3    {'age': 16, 'age_group': 'adolescent', 'gender...    treatment     False
# 4    {'age': None, 'age_group': '', 'gender': '', '...    treatment     False
# ..                                                 ...          ...       ...
# 826  {'age': None, 'age_group': '', 'gender': '', '...    diagnosis     False
# 827  {'age': None, 'age_group': '', 'gender': '', '...    treatment     False
# 828  {'age': None, 'age_group': '', 'gender': '', '...  reassurance     False
# 829  {'age': None, 'age_group': '', 'gender': '', '...    treatment     False
# 830  {'age': None, 'age_group': '', 'gender': '', '...    diagnosis      True
#
#                           comorbidities  \
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4                                    []
# ..                                  ...
# 826  [low B12 levels, intrinsic factor]
# 827                    [b12 deficiency]
# 828            [vitamin B12 deficiency]
# 829             [B12 deficiency, vegan]
# 830                                  []
#
#                                               triggers      frequency  \
# 0                                                   []     off and on
# 1                                                   []   intermittent
# 2                                                   []
# 3                                                   []
# 4                                           [lockdown]
# ..                                                 ...            ...
# 826                                                 []
# 827                                                 []  after 8 weeks
# 828                                                 []
# 829  [Gynest Cream, Beconase Nasal Spray, Benzoic A...
# 830                                                 []
#
#      query_complexity_score
# 0                         1
# 1                         3
# 2                         1
# 3                         6
# 4                         1
# ..                      ...
# 826                       4
# 827                       3
# 828                       2
# 829                       7
# 830                       6
#
# [831 rows x 14 columns]

# %%
df_org = pd.read_json(file_path_org, lines=True)
df_org
# Out:
#                                                symptoms  \
# 0     [{'name': 'bumps', 'anatomical_location': '', ...
# 1     [{'name': 'acne', 'anatomical_location': 'face...
# 2     [{'name': 'acne', 'anatomical_location': 'skin...
# 3     [{'name': 'red cheeks', 'anatomical_location':...
# 4     [{'name': 'acne', 'anatomical_location': 'skin...
# ...                                                 ...
# 2971  [{'name': 'floaters', 'anatomical_location': '...
# 2972  [{'name': 'vertical double vision', 'anatomica...
# 2973  [{'name': 'eye burning', 'anatomical_location'...
# 2974  [{'name': 'red eye', 'anatomical_location': 'e...
# 2975                                                 []
#
#                                                duration severity_overall  \
# 0     {'value': 'a couple months', 'normalized_days'...
# 1     {'value': '6 years', 'normalized_days': 2190, ...           severe
# 2     {'value': 'lately', 'normalized_days': 14, 'on...         moderate
# 3     {'value': '3 years', 'normalized_days': 1095, ...
# 4     {'value': '', 'normalized_days': 0, 'onset_typ...
# ...                                                 ...              ...
# 2971  {'value': '1.5 years', 'normalized_days': 547,...           severe
# 2972  {'value': 'recently', 'normalized_days': 0, 'o...
# 2973  {'value': '', 'normalized_days': 0, 'onset_typ...
# 2974  {'value': 'last few days', 'normalized_days': ...
# 2975  {'value': '5 days', 'normalized_days': 5, 'ons...
#
#                   anatomical_locations  \
# 0                                   []
# 1                               [face]
# 2                               [skin]
# 3     [cheeks, chin, between eyebrows]
# 4                               [skin]
# ...                                ...
# 2971             [right eye, left eye]
# 2972                            [eyes]
# 2973                             [eye]
# 2974                             [eye]
# 2975                       [right eye]
#
#                                            demographics       intent  \
# 0     {'age': None, 'age_group': '', 'gender': '', '...    diagnosis
# 1     {'age': 20, 'age_group': 'adult', 'gender': ''...    treatment
# 2     {'age': None, 'age_group': '', 'gender': '', '...    treatment
# 3     {'age': 16, 'age_group': 'adolescent', 'gender...    diagnosis
# 4     {'age': None, 'age_group': '', 'gender': '', '...    treatment
# ...                                                 ...          ...
# 2971  {'age': None, 'age_group': '', 'gender': '', '...    treatment
# 2972  {'age': None, 'age_group': '', 'gender': '', '...    diagnosis
# 2973  {'age': None, 'age_group': 'teenager', 'gender...    treatment
# 2974  {'age': 22, 'age_group': 'adult', 'gender': ''...    diagnosis
# 2975  {'age': None, 'age_group': '', 'gender': '', '...  reassurance
#
#       red_flag                   comorbidities  query_complexity_score  \
# 0        False                              []                       1
# 1        False                              []                       3
# 2        False                              []                       1
# 3        False                              []                       5
# 4        False                              []                       1
# ...        ...                             ...                     ...
# 2971     False                              []                       3
# 2972     False                   [astigmatism]                       3
# 2973     False                              []                       2
# 2974     False              [high cholesterol]                       1
# 2975     False  [cataract, gallbladder issues]                       0
#
#                                           original_text           label  \
# 0     can someone help?! I've had bumps like this of...            acne
# 1     I started getting acne since the age of 14 (I'...            acne
# 2     So i've been breaking out badly lately. I want...            acne
# 3     16 year old kid, about 3 years ago he was give...            acne
# 4     Been breaking out a lot due to this lockdown. ...            acne
# ...                                                 ...             ...
# 2971  I had 2 tears. I woke up with thousand small b...  Conjunctivitis
# 2972  Hi all,So recently I’ve noticed I’ve had some ...  Conjunctivitis
# 2973  I use preservative free eye drops almost every...  Conjunctivitis
# 2974  I am 22. The white part of my eye is red since...  Conjunctivitis
# 2975  I had right eye cataract surgery 5 days ago. L...  Conjunctivitis
#
#            category
# 0       Dermatology
# 1       Dermatology
# 2       Dermatology
# 3       Dermatology
# 4       Dermatology
# ...             ...
# 2971  Ophthalmology
# 2972  Ophthalmology
# 2973  Ophthalmology
# 2974  Ophthalmology
# 2975  Ophthalmology
#
# [2976 rows x 12 columns]

# %%
# df = df.rename(columns={"symptoms": "symptoms_df"})
df_org = df_org.rename(columns={"symptoms": "symptoms_org"})

# %%
df_merge = pd.merge(df, df_org, on="original_text", how="inner")
df_merge = df_merge[["original_text", "symptoms", "symptoms_org"]]
df_merge
# Out:
#                                          original_text  \
# 0    can someone help?! I've had bumps like this of...
# 1    I started getting acne since the age of 14 (I'...
# 2    So i've been breaking out badly lately. I want...
# 3    16 year old kid, about 3 years ago he was give...
# 4    Been breaking out a lot due to this lockdown. ...
# ..                                                 ...
# 946  I was diagnosed with low B12 levels and furthe...
# 947  Earlier this year I was diagnosed with b12 def...
# 948  I'm b12 deficiency. I was diagnosed with vitam...
# 949  Hello there I am booked in to have my first B1...
# 950  I have been going to my docs for over a year w...
#
#                                               symptoms  \
# 0    [{'name': 'bumps', 'normalized_name': None, 'a...
# 1    [{'name': 'acne', 'normalized_name': None, 'an...
# 2    [{'name': 'acne', 'normalized_name': None, 'an...
# 3    [{'name': 'redness', 'normalized_name': None, ...
# 4    [{'name': 'acne', 'normalized_name': None, 'an...
# ..                                                 ...
# 946  [{'name': 'vague feeling', 'normalized_name': ...
# 947  [{'name': 'memory loss', 'normalized_name': No...
# 948  [{'name': 'sore tongue', 'normalized_name': No...
# 949  [{'name': 'pins and needles', 'normalized_name...
# 950  [{'name': 'headaches', 'normalized_name': None...
#
#                                           symptoms_org
# 0    [{'name': 'bumps', 'anatomical_location': '', ...
# 1    [{'name': 'acne', 'anatomical_location': 'face...
# 2    [{'name': 'acne', 'anatomical_location': 'skin...
# 3    [{'name': 'red cheeks', 'anatomical_location':...
# 4    [{'name': 'acne', 'anatomical_location': 'skin...
# ..                                                 ...
# 946  [{'name': 'vague feeling', 'anatomical_locatio...
# 947  [{'name': 'memory loss', 'anatomical_location'...
# 948  [{'name': 'sore tongue', 'anatomical_location'...
# 949  [{'name': 'paresthesia', 'anatomical_location'...
# 950  [{'name': 'headaches', 'anatomical_location': ...
#
# [951 rows x 3 columns]

# %%
df_merge.to_csv("/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/merged_results_symptoms.csv", index=False)

# %%
df_org = df_org[['original_text','symptoms']]
df_org.to_csv("/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/dataset/symptoms_org.csv", index=False)

# %%
df = pd.read_json(file_path, lines=True)

# %%
len(df.severity_overall)
# Out:
# 831

# %%
file_path = "/home/maaz-rafiq/work/phd_thesis_tanveer/CamelMedAgents-RAG/intelligent_scraping/structured_queries.jsonl"

data = []

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        data.append(line)

print(data)
# Out:
# ['{"original_text": "can someone help?! I\'ve had bumps like this off and on for a couple months now and I\'m not sure if I am having an allergic reaction to something or if I\'m starting to get acne. Any advice is appreciated!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "bumps", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "a couple months", "normalized_days": 60, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "off and on", "query_complexity_score": 1}\n', '{"original_text": "I started getting acne since the age of 14 (I\'m 20 now). sometimes it is severe and sometimes it clears out completely. from the past 2 weeks i\'m having severe acne. it is big, painful and red. I don\'t know what type of acne this is. can someone tell me what i should do to clear this.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "pain", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "redness", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}], "duration": {"value": "6 years", "normalized_days": 2190, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face"], "demographics": {"age": 20, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "intermittent", "query_complexity_score": 3}\n', '{"original_text": "So i\'ve been breaking out badly lately. I want to try some home remedies, i saw that using colgate and vaseline could help. Has anyone tried this? If so, how did it work for you?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "skin", "severity": "badly"}], "duration": {"value": "lately", "normalized_days": 7, "onset_type": "acute"}, "severity_overall": "moderate", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}\n', '{"original_text": "16 year old kid, about 3 years ago he was given some prescribed acne meds by his doctor. Now, he has very red cheeks, it looks like he\'s constantly blushing, and generally red skin on his chin and between his eyebrows. Along with that, he tends to get pimples (some blackheads, some inflamed whiteheads) on his chin, in the same general area as the redness on his chin. The acne meds don\'t seem to be helping too much, it\'s just a twice daily face wash and clindamycin phosphate topical lotion. Haven\'t been to the doctor\'s recently, not sure if I even want to take him with all that\'s going on. He\'s never had acne on his cheeks where that red is, yet nothing seems to help. Wondering whether anyone might have any ideas as to if the acne meds could be worsening the redness if it is rosacea, or if something stronger is needed if it\'s acne. Thanks for any help!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "redness", "normalized_name": null, "anatomical_location": "cheeks", "severity": ""}, {"name": "redness", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "redness", "normalized_name": null, "anatomical_location": "between eyebrows", "severity": ""}, {"name": "pimples", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "blackheads", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "inflamed whiteheads", "normalized_name": null, "anatomical_loca ...

# %%
f = open(file_path, 'r')
    # Parsing the JSON file into a Python dictionary
for line in f:
    print(line)
# Out:
# {"original_text": "can someone help?! I've had bumps like this off and on for a couple months now and I'm not sure if I am having an allergic reaction to something or if I'm starting to get acne. Any advice is appreciated!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "bumps", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "a couple months", "normalized_days": 60, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "off and on", "query_complexity_score": 1}
#
# {"original_text": "I started getting acne since the age of 14 (I'm 20 now). sometimes it is severe and sometimes it clears out completely. from the past 2 weeks i'm having severe acne. it is big, painful and red. I don't know what type of acne this is. can someone tell me what i should do to clear this.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "pain", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "redness", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}], "duration": {"value": "6 years", "normalized_days": 2190, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face"], "demographics": {"age": 20, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "intermittent", "query_complexity_score": 3}
#
# {"original_text": "So i've been breaking out badly lately. I want to try some home remedies, i saw that using colgate and vaseline could help. Has anyone tried this? If so, how did it work for you?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "skin", "severity": "badly"}], "duration": {"value": "lately", "normalized_days": 7, "onset_type": "acute"}, "severity_overall": "moderate", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "16 year old kid, about 3 years ago he was given some prescribed acne meds by his doctor. Now, he has very red cheeks, it looks like he's constantly blushing, and generally red skin on his chin and between his eyebrows. Along with that, he tends to get pimples (some blackheads, some inflamed whiteheads) on his chin, in the same general area as the redness on his chin. The acne meds don't seem to be helping too much, it's just a twice daily face wash and clindamycin phosphate topical lotion. Haven't been to the doctor's recently, not sure if I even want to take him with all that's going on. He's never had acne on his cheeks where that red is, yet nothing seems to help. Wondering whether anyone might have any ideas as to if the acne meds could be worsening the redness if it is rosacea, or if something stronger is needed if it's acne. Thanks for any help!", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "redness", "normalized_name": null, "anatomical_location": "cheeks", "severity": ""}, {"name": "redness", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "redness", "normalized_name": null, "anatomical_location": "between eyebrows", "severity": ""}, {"name": "pimples", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "blackheads", "normalized_name": null, "anatomical_location": "chin", "severity": ""}, {"name": "inflamed whiteheads", "normalized_name": null, "anatomical_location": "chin", "severity": ""}], "duration": {"value": "3 years", "normalized_days": 1095, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["cheeks", "chin", "between eyebrows"], "demographics": {"age": 16, "age_group": "adolescent", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 6}
#
# {"original_text": "Been breaking out a lot due to this lockdown. Anyone have any at-home remedies that i can try?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "skin", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["lockdown"], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I'm 31 years old. I have been struggling acne and rosacea for years. i tried many kinds of medicines but they didn't work so i gave up on medicine. right now i am, only at times, using a tropical one, so i still have acne every now and then. but my biggest concern in rosacea, i have it all the times for at least 10 years. Is there someone can help me with this?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "rosacea", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "10 years", "normalized_days": 3650, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": 31, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "every now and then", "query_complexity_score": 2}
#
# {"original_text": "Maybe I am being too hopeful here but I would like to know if there are other treatments for Acne which is nodular and cystic/boils, other than Isotretinoin and all its variant names.I've been given 10mg starting dose of the drug by my Dermatologist a few weeks ago but I haven't taken it mostly because I worry about the side effects. I will be having a consultation soon with them on the phone and wonder how to explain to them why I haven't taken it so they will understand.I've been through a difficult time right now being stressed often with low mood, and been more anxious since the current events. And I thought taking this particular drug at this time would be a extra weight on my shoulders monitoring for side effects and I have dry skin already from eczema so taking this drug has been such a dilemma for me.I've suffered from bad acne suddenly since August last year. It is localised mostly on my face and cheeks but particularly bad on my neck and I've got scars from it. I took Lymecycline for a few months but it made no difference, the same with an over-the-counter cream.I get consistent whiteheads forming in different locations on my face but the worst are the nodular ones which turn into boils on my neck and these are quite common..I know I've been offered a treatment plan for it but as mentioned I am reluctant because of the side effects and my family think I should try everything before taking it.Are there other prescriptions such as topical Retinoids that could help, without serious potential side effects like Crohn's disease? What other treatments help? I've consumed dairy products for many years without bad acne and eaten the same foods for many months so it isn't likely to be dietary. Or maybe it is more stress or hormone related. What should I say to my Dermatologist? He says things like the topical solutions won't help without explanation.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "nodular acne", "normalized_name": null, "anatomical_location": "face, cheeks, neck", "severity": "severe"}, {"name": "cystic acne", "normalized_name": null, "anatomical_location": "neck", "severity": "severe"}, {"name": "whiteheads", "normalized_name": null, "anatomical_location": "face", "severity": "mild"}, {"name": "dry skin", "normalized_name": null, "anatomical_location": "", "severity": "mild"}, {"name": "eczema", "normalized_name": null, "anatomical_location": "", "severity": "mild"}, {"name": "scarring", "normalized_name": null, "anatomical_location": "neck", "severity": "moderate"}], "duration": {"value": "since August last year", "normalized_days": 365, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face", "cheeks", "neck"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["eczema"], "triggers": ["stress", "hormonal changes"], "frequency": "consistent", "query_complexity_score": 6}
#
# {"original_text": "I have been taking Isotretinoin (Roacccutane) for forty-four days now. I was first prescribed this medication on the 25th February, two months after my initial appointment with the dermatologist. So far, I have seen an improvement in my acne. My skin and scalp are very dry. There has been no change in my mood and I don't think I have any other side effects from taking it. Acne has affected my life for so long and I was happy that I was finally starting to see a change!The dermatologist was very reluctant to prescribe me the medication as the results of my initial blood test revealed I had high cholesterol. Never the less, I was initially prescribed Isotretinoin for 30 days (but was given 56 capsules) and would need a monthly review. I was due a second blood test on the 16th March and a follow up appointment on the 27th March, however due to coronavirus those appointments were cancelled and since then I have had radio silence from the dermatologist. With total appreciation and understanding of how busy everybody at the NHS is right now, I must admit that I do feel as if I have fallen through the net.Due to how serious this drug is I was told that I would need to be monitored on a monthly basis. That I would have been prescribed more medication depending on the results of my blood tests and how well I was reacting to the treatment. The dermatologist herself listed a whole bunch of scary side effects and I had to sign form to acknowledge this. So with that, I wonder how a patient taking a drug that is labelled with such adverse side effects can just be put aside and forgotten about. I have waited a long time to get this medication and it's also disappointing that the journey is about to come to an abrupt end just as I was starting to see results!I was just curious to know if anybody else has found themselves in this situation?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "dry skin", "normalized_name": null, "anatomical_location": "skin", "severity": ""}, {"name": "dry scalp", "normalized_name": null, "anatomical_location": "scalp", "severity": ""}], "duration": {"value": "forty-four days", "normalized_days": 44, "onset_type": "acute"}, "severity_overall": "", "anatomical_locations": ["skin", "scalp"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "reassurance", "red_flag": false, "comorbidities": ["high cholesterol"], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "I suffer acne for years and along with it i also suffer constantly from anxiety and depression.now i still have acne, even though i have tried many kinds of medicine including Isotretinoina, i'm depressed every time i look at my wrecked face. i got a lot of scars on my nose... ", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "anxiety", "normalized_name": null, "anatomical_location": "", "severity": "constant"}, {"name": "depression", "normalized_name": null, "anatomical_location": "", "severity": "constant"}, {"name": "scars", "normalized_name": null, "anatomical_location": "nose", "severity": ""}], "duration": {"value": "years", "normalized_days": 1095, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["face", "nose"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "constant", "query_complexity_score": 4}
#
# {"original_text": "I am 2.5 weeks into my isotretinoin course (20mg daily), and have developed a weird rash on my hand. There are some other small patches on upper arms and shoulders too. Is this normal? What should I do to treat this? I have been using a small amount of 1% hydrocortisone on the patches and seems to be helping slightly. Is this safe and/or a good treatment? Cheers", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "rash", "normalized_name": null, "anatomical_location": "hand", "severity": ""}, {"name": "rash", "normalized_name": null, "anatomical_location": "upper arms", "severity": ""}, {"name": "rash", "normalized_name": null, "anatomical_location": "shoulders", "severity": ""}], "duration": {"value": "2.5 weeks", "normalized_days": 17, "onset_type": "acute"}, "severity_overall": "", "anatomical_locations": ["hand", "upper arms", "shoulders"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["isotretinoin"], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I never used to suffer from severe acne like this as far as I can remember. I did get bad acne as a teenager but not red, cystic bunches like this. For several months I've had on and off pimples or whiteheads, mostly being on my face. But now they are nodular and recently came in lumps especially on my neck. Most of my acne is on my face and neck but I get it on my shoulders and upper arms too.It did start to happen when I was running into financial difficulty looking for work, working a stressful job and thinking about rent payments. I suppose the cause is emotional. I'm feeling better but the acne keeps coming back.My dermatologist suggested me to try Lymecycline antibiotic. I took the whole course but it didn't clear my acne. He then suggested I try Accutane on a low dose after noticing my lumps (not from these pictures though) I recently gave up a blood sample for it and seeing him mid March. I am nervous taking such a drug because of the reported effects and my eczema which has been better recently. My dermatologist really rushes through appointments and I'm unable to get very detailed responses from him, probably as he's always really busy.Do you think its worth taking Accutane for cystic, tender acne like such? Or should I make a GP appointment to get another professional opinion?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "acne", "normalized_name": null, "anatomical_location": "neck", "severity": "severe"}, {"name": "acne", "normalized_name": null, "anatomical_location": "shoulders", "severity": "moderate"}, {"name": "acne", "normalized_name": null, "anatomical_location": "upper arms", "severity": "moderate"}, {"name": "eczema", "normalized_name": null, "anatomical_location": "", "severity": "better recently"}], "duration": {"value": "several months", "normalized_days": 90, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face", "neck", "shoulders", "upper arms"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["eczema"], "triggers": ["stress", "emotional"], "frequency": "on and off", "query_complexity_score": 2}
#
# {"original_text": "Hello everyone, 23yo male here. I used to have big acne problems as a teenager and im wondering if there is way to fix the marked landscape left behind. Please only comment if you are a medical professional. Thank you", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne scars", "normalized_name": null, "anatomical_location": "face", "severity": ""}], "duration": {"value": "several years", "normalized_days": 1825, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["face"], "demographics": {"age": 23, "age_group": "young adult", "gender": "male", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "It used to itch a little bit when I was starting to notice it months ago. This never happened before but it's never gone away and it's progressively getting worse. Now it doesn't itch at all but has definitely gotten both bigger in size, not just overall radius, and has a brighter redness to it now as well. Yes I use soap and I scrub myself.I hope this isn't anything to worry about although for being married a year and a half and now this comes right out of the blue just after a couple suspicious behaviours are brought out from my wife, I do hope that this isn't meaning she's cheating such as with contracting an STD and then sharing it with me but as with no strong reason for suspicion as of yet, I still don't know if she is. I am hoping she is being honest but this does have me concerned about my health. (Pics below).Also, we are both 24 years old, this rash or whatever it is has only shown up on my butt and I have fairly good hygiene. My underwear is breathable and I never wear the same pair the next day. I'm shocked thinking about it considering my family goes my entirely different standards.Thanks in advance", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "rash", "normalized_name": null, "anatomical_location": "buttocks", "severity": "progressively worse"}, {"name": "redness", "normalized_name": null, "anatomical_location": "buttocks", "severity": "brighter"}, {"name": "increase in size", "normalized_name": null, "anatomical_location": "buttocks", "severity": "bigger"}], "duration": {"value": "months", "normalized_days": 90, "onset_type": "chronic"}, "severity_overall": "progressively worse", "anatomical_locations": ["buttocks"], "demographics": {"age": 24, "age_group": "adult", "gender": "male", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 3}
#
# {"original_text": "i have never had a problem with acne. im 25 and im constantly getting acne on my jaw line and near my lips but not on my lips. does anyone know what could cause this? my diet hasnt changed. ", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "jaw line", "severity": ""}, {"name": "acne", "normalized_name": null, "anatomical_location": "near lips", "severity": ""}], "duration": {"value": "constantly", "normalized_days": 0, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["jaw line", "near lips"], "demographics": {"age": 25, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "constantly", "query_complexity_score": 1}
#
# {"original_text": "so i get spots if i shave with a razor and i can understand why. but its been many years that i am shaving with trimmer and yet i get spots!i have severe keratosis pilaris on my arms and i guess hey are on my face too because my face is very bumpy and every pore is blocked. i tried many ways suggested by here and many other places for unblocking pores, exfoliating and many more but they didn't help.also the hair on my face (full face, beard and everywhere else) comes off when i grip on it by nails. its like 1 hair is ok but another tiny hair is stuck on to the side of the other one, and that's what comes off.i see ppl shaving in the morning and leaving off to work but when i shave i have to go shower and wash my face a thousand times because those tiny hairs that get cut by the trimmers get very itchy so i cant say i left it on my face and caused a spot.any help? im just so tired of this situation", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "spots", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "keratosis pilaris", "normalized_name": null, "anatomical_location": "arms", "severity": "severe"}, {"name": "bumpy skin", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "blocked pores", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "itchiness", "normalized_name": null, "anatomical_location": "face", "severity": ""}], "duration": {"value": "many years", "normalized_days": 3650, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face", "arms"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["shaving with razor", "shaving with trimmer"], "frequency": "", "query_complexity_score": 5}
#
# {"original_text": "i was getting itchy on my butt cheek and been itching and not sure what these bumps are.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "itchiness", "normalized_name": null, "anatomical_location": "butt cheek", "severity": ""}, {"name": "bumps", "normalized_name": null, "anatomical_location": "butt cheek", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["butt cheek"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "I started suffering from chest and back acne from about the age of 39. I'm now 41 and am still suffering. Have tried many over the counter treatments and keep my skin as clean as possible. It really affects my self confidence! Any advice would be appreciated. Thanks", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "chest", "severity": ""}, {"name": "acne", "normalized_name": null, "anatomical_location": "back", "severity": ""}], "duration": {"value": "2 years", "normalized_days": 730, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["chest", "back"], "demographics": {"age": 41, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "Hello,Hope I post in the right place...(Pictures)https://www.dropbox.com/s/4xqfeyqviv26h09/79308007_456553608333211_1535580902879395840_n.jpg?dl=0https://www.dropbox.com/s/vl0fxwpwwa2rtt6/79107815_556636441834155_5880687737287213056_n.jpg?dl=0If anyone could help me it would be great. I have been to the doctors for this and they told me it was pilonidal sinus and that the only solution for this is surgery and it’s not 100% guaranteed that the problem will go away (Chance of it coming back).I am getting these spots/holes every week in the same area. The red spot/lump is on my right bum cheek right at the top where my ass crack starts (sorry for the language). It happens every week and it is always bursting with blood and blood clots.Then I have 3 holes on my ass crack near the top which is always giving out sticky pus and blood. I don’t know If it is related but my lower back is hurting very badly and so are my muscles in general. Can someone tell me exactly what it is and tell me some solution for this other than surgery. I would do surgery but the doctor says it’s not 100% guaranteed solution as they can always come back therefore I am looking for some other solution like maybe some anti-biotic or cream etc.Thank you.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "pilonidal sinus", "normalized_name": null, "anatomical_location": "top of buttock cleft", "severity": ""}, {"name": "red spot/lump", "normalized_name": null, "anatomical_location": "right buttock cheek", "severity": ""}, {"name": "pain", "normalized_name": null, "anatomical_location": "lower back", "severity": "very bad"}, {"name": "muscle pain", "normalized_name": null, "anatomical_location": "general", "severity": ""}], "duration": {"value": "every week", "normalized_days": 7, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["top of buttock cleft", "right buttock cheek", "lower back"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "weekly", "query_complexity_score": 4}
#
# {"original_text": "i've had pretty much clear skin since january but about 2 weeks after moving to university my chin started looking like this? ive googled it and was thinking it could be perioral demermatitis but im not sure because thats normally caused me steroids? however i have been using a new toothpaste while at uni which could maybe have caused it? anyone know why this had happened and how i can treat it?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "rash", "normalized_name": null, "anatomical_location": "chin", "severity": ""}], "duration": {"value": "2 weeks", "normalized_days": 14, "onset_type": "acute"}, "severity_overall": "", "anatomical_locations": ["chin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": ["new toothpaste"], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "anyone been on this for cystic acne? derm put me on it and was wondering if it works side effects etc ... my blood pressure is always on lower side so wats the risks ? does this cause cancer ?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "cystic acne", "normalized_name": null, "anatomical_location": "skin", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["low blood pressure"], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I'm 25 and always had fairly clear skin but about a year ago startes getting a few spots. As they began to get worse i started trying over the counter treatments but nothing worked. Saw a dermatologist a few months ago and she suggested a new skin regime but nothing has worked. Tried epiduo and duac and have now been given lymecycline to try as my skin is the worst it has ever been. It appears to get better for a few days then breaks out even worse. Has anyone had experiences with lymecycline or similar experiences and has any advice? Got to the point where I wont leave the house.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "skin", "severity": "severe"}], "duration": {"value": "about a year", "normalized_days": 365, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["skin"], "demographics": {"age": 25, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "intermittent", "query_complexity_score": 1}
#
# {"original_text": "I have severe acne on my face from last 6 months. Even after consulting dermatologist, I'm not getting results. Can anyone have any solution?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}], "duration": {"value": "6 months", "normalized_days": 180, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I made a huge mistake by picking at a black head and now the skin underneath has turned pink. Does it eventually fade away & turn back to my natural skin complexion?I’m also a fashion blogger so this is a huge inconvenience but I’ll be fine lol.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "pink skin", "normalized_name": null, "anatomical_location": "skin", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "reassurance", "red_flag": false, "comorbidities": [], "triggers": ["picking at a blackhead"], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Does anyone know what exactly this thing is? on top of my eyelid. it does not hurt nor discharge any fluid. ", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "lump", "normalized_name": null, "anatomical_location": "eyelid", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["eyelid"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Is the acne?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Is the acne?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Hi everyone,I'm a 19-year-old male and I've been struggling with acne since I was about 16. When I was in high school, I used to get cystic acne on my checks and chin and papules on my forehead and cheeks, and whiteheads on my lips and nose FREQUENTLY. There was always at least one or two noticeable pimples on my face at all times. In the summer before leaving for college I broke out tremendously. I didnt want to leave the house. As the first week or two of college passed, I started growing a beard, which made me happy because it hid the acne very well. I guess it took the attention off of it. I noticed my acne to be less frequent and severe but still had some here and there. Fast forward to today, Im starting to break out more and more. Ive changed a lot about my routines. Ive started taking multivitamins (without iodine and low biotin), zinc, and fish oils, Ive cut out dairy from my diet, I try to drink as much water as possible, I exercise, I wash and change my pillow cases more often, I wash my beard,, but im getting more and more acne than i did before.Im just sick of seeing my face look gross while everyone is enjoying flawless skin. I just dont understand what im doing wrong.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "cystic acne", "normalized_name": null, "anatomical_location": "cheeks and chin", "severity": "severe"}, {"name": "papules", "normalized_name": null, "anatomical_location": "forehead and cheeks", "severity": "moderate"}, {"name": "whiteheads", "normalized_name": null, "anatomical_location": "lips and nose", "severity": "mild"}], "duration": {"value": "3 years", "normalized_days": 1095, "onset_type": "chronic"}, "severity_overall": "moderate", "anatomical_locations": ["cheeks", "chin", "forehead", "lips", "nose"], "demographics": {"age": 19, "age_group": "adolescent", "gender": "male", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["diet", "routine changes"], "frequency": "frequent", "query_complexity_score": 3}
#
# {"original_text": "i first noticed it a month ago. ever since it has continued to grow. its making it very hard to walk around a lot. the skin on top is soft, but whatever is underneath has hardened. before it was more fluid. what should i do. Uploading file...", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "swelling", "normalized_name": null, "anatomical_location": "leg", "severity": "severe"}, {"name": "hardening", "normalized_name": null, "anatomical_location": "underneath the skin", "severity": "moderate"}], "duration": {"value": "1 month", "normalized_days": 30, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["leg", "underneath the skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "Hai fellows, i am new to this forum. I am suffering from skin problems. Can anyone suggest any skin care home remedies to improve my skin.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "skin problems", "normalized_name": null, "anatomical_location": "skin", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I have hormonal acne that has started to spread to my forehead and chin. I have super fair skin and every spot is leaving me with dark purple scars. Last year my skin was clear as I had been on Yasmin for around 8 months. 6 months ago they changed my pill to Lucette, which they said was just a different brand name, however I have broke out since and am unable to control it. They said they no longer fund Yasmin. I have tried all the products below and strict skincare regimes but none of them work. I'm now getting really deep painful cystic spots that are staying under my skin for months!Anyone got any ideas?Products tried:ZinerytDuacAcnecideDoxycyclineNumerous other contraceptive pillsTpoical and oral antibiotics combined", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "hormonal acne", "normalized_name": null, "anatomical_location": "forehead and chin", "severity": ""}, {"name": "dark purple scars", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "deep painful cystic spots", "normalized_name": null, "anatomical_location": "skin", "severity": "severe"}], "duration": {"value": "6 months", "normalized_days": 180, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["forehead", "chin", "face", "skin"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["change in contraceptive pill"], "frequency": "", "query_complexity_score": 3}
#
# {"original_text": "i dont know if this is the right forum to post but i will post it.I got some kind of rash circles on my leg 3 or 4 days ago,at the time,there were just 3 5 little rash kind bumps on the back of my left leg,it doesnt hurt,i dont feel the need to scratch it,nothing.I went to the doctor,and he said that its probably a mosqito bite,but im sure it isnt.i dont get bitten by mosqitoes often(maybe once or twice the whole summer),and on our way to the doctor i spotted two more rash little circles on the same leg.I got some kind of cream to put on twice a day,it started helping and i think if i continue using it,they will disappear.the only problem is,that rash circles are spreading,now i have like 5 6 on both legs.im sorry for my bad english,but i think you will understand what i mean.Does anyone know what are these little reddish rash circles? btw im 15 year old", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "rash", "normalized_name": null, "anatomical_location": "legs", "severity": "mild"}], "duration": {"value": "3 or 4 days", "normalized_days": 4, "onset_type": "acute"}, "severity_overall": "mild", "anatomical_locations": ["legs"], "demographics": {"age": 15, "age_group": "adolescent", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "hi everyone. in just wondering has anyone any solutions or homemade remedies for acne. Can you give me advice on how you got rid of your acne if youve had it. im 27 and i have it on my face. im so concious about it and I really need some help. i absolutely hate it. i feel so ugly with it. i cant leave my house without makeup. and id really live to go a day without having to wear it. any advice is appreciated thank u", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["face"], "demographics": {"age": 27, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Hi,I'd be grateful to hear from anyone who has suffered with bad skin after stopping Dianette. My situation is getting me down.Basically I've taken Dianette for the past 14 years. I went on it due to oily skin and acne which it was absolutely brilliant for. Anyway, I had to stop taking it 3 months ago. Within a month my skin was getting oilier with few small spots. Now I'm at a stage where my skin is so oily my face will start to shine within minutes of cleansing it. I'm endlessly having to blot my face all day. My hair gets greasy much faster than it used to. My chest and back are now spotty, and my face in addition to being extremely oily is covered in spots. My chin is by far the worst with big, red, cystic acne.Is there any hope that this will settle down in time or was the pill just masking my problem this whole time? More than the acne for me the worst part is my greasy skin.I can't go on to an alternative OCP at the moment. I'm using benzoylperoxide gel but it'snlt as effective as I'd hoped.I know there are many worse problem to have than something so superficial but its so damaging to confidence. I'm 30 and never imagined I'd have bad acne at this age. I can't even cover it up because my skin is so oily it just causes make up to slide off.Does anyone have any experience with this and any tips on possible treatments?Thank you in advance.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "oily skin", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "severe"}, {"name": "greasy hair", "normalized_name": null, "anatomical_location": "scalp", "severity": "moderate"}, {"name": "acne", "normalized_name": null, "anatomical_location": "chest", "severity": "moderate"}, {"name": "acne", "normalized_name": null, "anatomical_location": "back", "severity": "moderate"}, {"name": "cystic acne", "normalized_name": null, "anatomical_location": "chin", "severity": "severe"}], "duration": {"value": "3 months", "normalized_days": 90, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face", "scalp", "chest", "back", "chin"], "demographics": {"age": 30, "age_group": "adult", "gender": "female", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": ["stopping Dianette"], "frequency": "constant", "query_complexity_score": 6}
#
# {"original_text": "Uh I'm not entirely sure who to ask this so I'm asking here i guess. a couple months ago i was sitting down and i noticed my labia was really uncomfortable. So i went to the bathroom and there was a bump there. It was painful to touch and squeeze etc. It was really bothering me so i kept on squeezing. (i know I'm not supposed to squeeze things like that but it hurt to much if i didn't) after a couple minutes of squeezing it finally popped. light yellow liquid came oozing out. after that liquid came out it oozed blood as well. well flash forward to today and i was sitting down again, moved my leg and thought, god damn this hurts my labia. and well sure enough another bump was there. same thing happened. although it was on a different side of my labia. Ive never had sex but i have masturbated. i would really like to know what was on my labia.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "painful bump", "normalized_name": null, "anatomical_location": "labia", "severity": "painful"}, {"name": "discomfort", "normalized_name": null, "anatomical_location": "labia", "severity": ""}], "duration": {"value": "a couple months", "normalized_days": 60, "onset_type": "chronic"}, "severity_overall": "painful", "anatomical_locations": ["labia"], "demographics": {"age": null, "age_group": "", "gender": "female", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "![image](https://patient.azureedge.net/forums/images/upload-sm/1253418-636981591986885443.jpg)Male, 22 yo.This is going on for 3 years, with new breakouts every day.Tried bazirone, solantra, benzoilbenzonate, zenerit, no diary.Facial hair doesn't grow anywhere but upper lip area.Sometimes I feel sick after fatty foods, milk and sausages.I also have an odd shaped gallblader, but the doctor said it's okay and was probably like that since birth.", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": ""}, {"name": "nausea", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "impaired facial hair growth", "normalized_name": null, "anatomical_location": "face", "severity": ""}], "duration": {"value": "3 years", "normalized_days": 1095, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["face"], "demographics": {"age": 22, "age_group": "adult", "gender": "male", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["odd shaped gallbladder"], "triggers": ["fatty foods", "milk", "sausages"], "frequency": "daily", "query_complexity_score": 3}
#
# {"original_text": "Can anybody offer some advice regarding hormonal acne pl? Getting desperate for adult daughter who is really depressed due to relapse. She is 43 and during her life time had three lots of accutane. Last one was in 2007, Her acne has come back, they are cystic ones mainly on chins and are so painful. I do not know what advice to offer. DUAC does not seem to help. She does not wants pills if she can avoid it. She is considering seeing a herbalist and exploring alternatives therapy. Has anybody tried anything else with success . DIET OR SUPPLEMENTS? CHINESE MEDICINE OR DERMATOLOGIST privately as do not think gp will refer her. She cannot even get appt to see gp she is seeing the nurse. Seeing a dermatologist or chinese practitioner cost about the same £200 for consultation. It is affected her psychologically and any advice and tips from fellow sufferers will be greatly appreciated She is often tearful on the phone with. Thanks", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "cystic acne", "normalized_name": null, "anatomical_location": "chin", "severity": "painful"}], "duration": {"value": "relapse", "normalized_days": 0, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["chin"], "demographics": {"age": 43, "age_group": "adult", "gender": "female", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "I'm 28 years old and still suffering from dreaded acne for over 18 years now. Been trying everything to get rid of it but just keeps getting worse. Anyone experiencing the same fate?I'm 28 years old and still suffering from dreaded acne for over 18 years now. Been trying everything to get rid of it but just keeps getting worse. Anyone experiencing the same fate?", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "skin", "severity": "worse"}], "duration": {"value": "18 years", "normalized_days": 6570, "onset_type": "chronic"}, "severity_overall": "worse", "anatomical_locations": ["skin"], "demographics": {"age": 28, "age_group": "adult", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 1}
#
# {"original_text": "Sorry for the disgusting title, but I need some advice. Im 18yo male and Ive had trouble with acne on my face which I can manage. Ill get some cysts at my eyebrows, whiteheads on my nose and lip, and the ones in between on my cheeks. They come one by one, but in the last day or two my back (which also usually has two or three pimples at a time) sudden has a severe breakout. For the last 5 weeks, Ive had an unhealthy lifestyle (5hr sleep, 20mg adderal, soccer every other night, long work days, dusty work environment), is this my body finally giving in to the stress or is this something else?Thanks,Mike", "label": "acne", "category": "Dermatology", "symptoms": [{"name": "acne", "normalized_name": null, "anatomical_location": "face", "severity": "manageable"}, {"name": "cysts", "normalized_name": null, "anatomical_location": "eyebrows", "severity": ""}, {"name": "whiteheads", "normalized_name": null, "anatomical_location": "nose and lip", "severity": ""}, {"name": "pimples", "normalized_name": null, "anatomical_location": "cheeks", "severity": ""}, {"name": "severe breakout", "normalized_name": null, "anatomical_location": "back", "severity": "severe"}], "duration": {"value": "5 weeks", "normalized_days": 35, "onset_type": "chronic"}, "severity_overall": "severe", "anatomical_locations": ["face", "eyebrows", "nose", "lip", "cheeks", "back"], "demographics": {"age": 18, "age_group": "adolescent", "gender": "male", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": [], "triggers": ["stress", "unhealthy lifestyle", "dusty work environment"], "frequency": "one by one, sudden severe breakout", "query_complexity_score": 5}
# ...
#
# {"original_text": "In 1999 I was diagnosed with VB12 deficiency, was having injections for the first year. Then i was feeling a burning sensation in my back, always had the injection in right thigh. I told my consultant and the injection was put in my left thigh. Three days later I was doubled up in pain and could not walk. I was like this for 3 months, Then I was able to walk short distances but was all scooped over and had to use a wheelchair. I stopped the injections This lasted for another 7 months. In 2002 I had a schillings test done but I was getting over food poisoning but I still had to have the test. So another VB12 injection in my right arm and a capsule to swollow. within a few days my right hand was so painful and my hand started to claw. Went back to the consultant and she said she could not understand it. But because the test never worked, I had to have another test in March 2003, same procedure, but injection put in left arm. This time the pain started in my hand and tremendious burning also within a few months my toes started to hurt pain and burning. I refused to have any more injections. I could not work or even do much for myself. I was still under the consultant and in 2008 my whole body was starting to react to not having the VB12 and I was told. \" If you do not have VB12 you will eventually die my white cells was over taking my red cells. My husband was so shocked he spent 3 month on internet to find a VB12 I could take. Yes bless him he found a sub ligual called.methylcobalamin. At first i took one every day for a month. Had a blood test done and found my levels were too high, so now I take one every 3 days and my blood count is good. The only thing is I am still paralised and have a clawed hand and sensitive to the touch and still very painful. But after 13 years it's part of my life and my left hand still burns and my toes are painful still, also I still cannot work. But my husband found my cure not the doctors. But sadly he died in 2010 from lung cancer.Has anybody els had a reaction to VB12 injections.", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "burning sensation", "normalized_name": null, "anatomical_location": "back", "severity": ""}, {"name": "pain", "normalized_name": null, "anatomical_location": "right hand", "severity": ""}, {"name": "clawed hand", "normalized_name": null, "anatomical_location": "right hand", "severity": ""}, {"name": "pain", "normalized_name": null, "anatomical_location": "toes", "severity": ""}, {"name": "burning sensation", "normalized_name": null, "anatomical_location": "left hand", "severity": ""}, {"name": "paralysis", "normalized_name": null, "anatomical_location": "general", "severity": ""}, {"name": "sensitivity to touch", "normalized_name": null, "anatomical_location": "general", "severity": ""}], "duration": {"value": "13 years", "normalized_days": 4745, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["back", "right hand", "toes", "left hand", "general"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "reassurance", "red_flag": false, "comorbidities": ["VB12 deficiency"], "triggers": ["VB12 injections"], "frequency": "", "query_complexity_score": 7}
#
# {"original_text": "Im Vitamin b12 deficiency.. In 5 weeks I've had 5 injections. I was told the next one is April 8th and every 3 months after that.. im also peri menopause.. I was told I should be getting injections every month.. I still have tingling in my finger tips and of and on lightheaded.. I asked my doctor if I could have the injections every month he said no The 5 injections were a good enough top up.. my reading was 160 on December 12th 2014.. my iron etc were perfect in the blood test.. im not anemic.. The doctor said the lightheaded and tingling in my finger tips could be the peri menopause.. im 43 and I'm not a vegetarian.. I can't absorb b12.. I'm on centrum at the moment.i bought them myself. I'm trying to get sublingual that goes under the tongue but in ireland I can't get it anywhere.. If I do get some can i still get my 3 monthly injections.. any advice please...", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "tingling", "normalized_name": null, "anatomical_location": "finger tips", "severity": ""}, {"name": "lightheadedness", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "5 weeks", "normalized_days": 35, "onset_type": "acute"}, "severity_overall": "", "anatomical_locations": ["finger tips"], "demographics": {"age": 43, "age_group": "adult", "gender": "female", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["Vitamin B12 deficiency", "peri menopause"], "triggers": [], "frequency": "off and on", "query_complexity_score": 2}
#
# {"original_text": "Been having b12 injections for 3 years now for panisous anemia i have them every 90 days, but recently I've been feeling exhausted well before the injection is due,the last injection however has not helped at all iam constantly tired and frozen all the time. Wondering if anyone can help me with a bit of advice. ", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "exhaustion", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "tiredness", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "feeling cold", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "3 years", "normalized_days": 1095, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["pernicious anemia"], "triggers": [], "frequency": "constantly", "query_complexity_score": 3}
#
# {"original_text": "I was diagnosed with low B12 levels and further tests revealed that I had intrinsic factor.I was given the 6 injection course and was told I would have another in 12 weeks then again and then blood tested again. 6 weeks since my last injection and my symptoms are back. Feeling vague, tired, lethargic, irritated etc. How can it be that I have intrinsic factor but obviously have low B12?is it likely something else is going on? - any ideas/suggestions?", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "vague feeling", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "tiredness", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "lethargy", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "irritation", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "6 weeks since last injection", "normalized_days": 42, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": [], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": false, "comorbidities": ["low B12 levels", "intrinsic factor"], "triggers": [], "frequency": "", "query_complexity_score": 4}
#
# {"original_text": "Earlier this year I was diagnosed with b12 deficiency and started having injections, I found the symptoms I have came back after 8 weeks but my doctor refuses to up my dosage. I feel like I'm going mad and that they don't believe me. I have bad memory loss and feel irrational after the 8 weeks and my gi symptoms return. Is there any other way to supplement this? I know I can take tablets but I don't know how good they would be? I need help ", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "memory loss", "normalized_name": null, "anatomical_location": "brain", "severity": "bad"}, {"name": "irrational feelings", "normalized_name": null, "anatomical_location": "brain", "severity": ""}, {"name": "gastrointestinal symptoms", "normalized_name": null, "anatomical_location": "gastrointestinal tract", "severity": ""}], "duration": {"value": "earlier this year", "normalized_days": 240, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["brain", "gastrointestinal tract"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["b12 deficiency"], "triggers": [], "frequency": "after 8 weeks", "query_complexity_score": 3}
#
# {"original_text": "I'm b12 deficiency. I was diagnosed with vitamin b12 deficiency in December 12th 2014. I've had 4 weekly injections so far.i get 1 more on Monday. Then every 3 months. I know it gets stored in the liver but how long will the 5 injections last. Before the 3 month injection. I'm on neo-cytamen 1000 micrograms. I'm scared confused I don't understand this.. my stomach wont produce b12.. I'm taking centrum for all the other vitamins because I don't know what else to do. My tongue is sore and the roof of my mouth.", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "sore tongue", "normalized_name": null, "anatomical_location": "tongue", "severity": ""}, {"name": "sore mouth roof", "normalized_name": null, "anatomical_location": "roof of mouth", "severity": ""}], "duration": {"value": "since December 12th 2014", "normalized_days": 3590, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["tongue", "roof of mouth"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "reassurance", "red_flag": false, "comorbidities": ["vitamin B12 deficiency"], "triggers": [], "frequency": "", "query_complexity_score": 2}
#
# {"original_text": "Hello there I am booked in to have my first B12 shot tomorrow as I believe I am B12 deficient. My reading is 282 and I have pins and needles in my left foot, dizziness, eyesight issues and generally feeling not real. I really believe I need medication fast. Have had extensive tests including MRI, brain scan etc and nothing comes up hence my current theory of B12 deficiency (I'm vegan) The problem I have is that I have had serious side effects to Gynest Cream (contains Benzoic Acid) and Beconase Nasal Spray and believe its probably the preservative. These include tongue numbness, confusion, blurred vision, dizziness. I am very worried that I could suffer an allergic reaction to the Benzyl Alcohol in the B12 shots. Is it possible to have a B12 shot without such an ingredient? Is the only alternative oral supplements which I fear will not be strong enough for me given my current symptoms. I really dont know what to do. Many many thanks Tracey", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "pins and needles", "normalized_name": null, "anatomical_location": "left foot", "severity": ""}, {"name": "dizziness", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "eyesight issues", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "feeling not real", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "tongue numbness", "normalized_name": null, "anatomical_location": "tongue", "severity": ""}, {"name": "confusion", "normalized_name": null, "anatomical_location": "", "severity": ""}, {"name": "blurred vision", "normalized_name": null, "anatomical_location": "", "severity": ""}], "duration": {"value": "", "normalized_days": 0, "onset_type": ""}, "severity_overall": "", "anatomical_locations": ["left foot", "tongue"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "treatment", "red_flag": false, "comorbidities": ["B12 deficiency", "vegan"], "triggers": ["Gynest Cream", "Beconase Nasal Spray", "Benzoic Acid", "Benzyl Alcohol"], "frequency": "", "query_complexity_score": 7}
#
# {"original_text": "I have been going to my docs for over a year with different issues from headaches, shortness of breath, chest pains, slurred speech, sore mouth,fatigue, and the last bloods I got took were weakly positive antibodies for pa she never said anything. When I looked up pa I have all the symptoms should I go back to my doctor and tell her??", "label": "B12 Deficiency", "category": "Hematology / Nutritional", "symptoms": [{"name": "headaches", "normalized_name": null, "anatomical_location": "head", "severity": ""}, {"name": "shortness of breath", "normalized_name": null, "anatomical_location": "respiratory system", "severity": ""}, {"name": "chest pains", "normalized_name": null, "anatomical_location": "chest", "severity": ""}, {"name": "slurred speech", "normalized_name": null, "anatomical_location": "speech", "severity": ""}, {"name": "sore mouth", "normalized_name": null, "anatomical_location": "mouth", "severity": ""}, {"name": "fatigue", "normalized_name": null, "anatomical_location": "general", "severity": ""}], "duration": {"value": "over a year", "normalized_days": 365, "onset_type": "chronic"}, "severity_overall": "", "anatomical_locations": ["head", "respiratory system", "chest", "speech", "mouth", "general"], "demographics": {"age": null, "age_group": "", "gender": "", "pregnancy_status": ""}, "intent": "diagnosis", "red_flag": true, "comorbidities": [], "triggers": [], "frequency": "", "query_complexity_score": 6}

# %%
f[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f[0]
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
# Out:
# _io.TextIOWrapper
